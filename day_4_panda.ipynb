# %%
import pandas as pd
import numpy as np
# Out:
# C:\Users\Ryzen\AppData\Local\Temp\ipykernel_4624\2162656668.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df=pd.read_csv(r"E:\New folder\gap.csv")

# %%
df.rename(columns={'country':'COUNTRY','gdpPercap':'GDP'})
# Out:
#           COUNTRY continent  year  lifeExp       pop         GDP iso_alpha  \
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
# ...           ...       ...   ...      ...       ...         ...       ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306       ZWE
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786       ZWE
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960       ZWE
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623       ZWE
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298       ZWE
#
#       iso_num
# 0           4
# 1           4
# 2           4
# ...

# %%
df
# Out:
#           country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
# ...           ...       ...   ...      ...       ...         ...       ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306       ZWE
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786       ZWE
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960       ZWE
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623       ZWE
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298       ZWE
#
#       iso_num
# 0           4
# 1           4
# 2           4
# ...

# %%
df.rename(columns={'country':'COUNTRY','gdpPercap':'GDP'},inplace=True)

# %%
df
# Out:
#           COUNTRY continent  year  lifeExp       pop         GDP iso_alpha  \
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
# ...           ...       ...   ...      ...       ...         ...       ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306       ZWE
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786       ZWE
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960       ZWE
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623       ZWE
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298       ZWE
#
#       iso_num
# 0           4
# 1           4
# 2           4
# ...

# %%
df.rename(columns={'country':'COUNTRY','gdpPercap':'GDP'},inplace=False)
# Out:
#           COUNTRY continent  year  lifeExp       pop         GDP iso_alpha  \
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
# ...           ...       ...   ...      ...       ...         ...       ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306       ZWE
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786       ZWE
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960       ZWE
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623       ZWE
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298       ZWE
#
#       iso_num
# 0           4
# 1           4
# 2           4
# ...

# %% [markdown]
# ## Fetch the value based on the index position or index coulmns

# %% [markdown]
# # Lookup func,hlookup v look

# %% [markdown]
# # set index()

# %%
temp=df.set_index('year')

# %%
temp
# Out:
#           COUNTRY continent  lifeExp       pop         GDP iso_alpha  iso_num
# year
# 1952  Afghanistan      Asia   28.801   8425333  779.445314       AFG        4
# 1957  Afghanistan      Asia   30.332   9240934  820.853030       AFG        4
# 1962  Afghanistan      Asia   31.997  10267083  853.100710       AFG        4
# 1967  Afghanistan      Asia   34.020  11537966  836.197138       AFG        4
# 1972  Afghanistan      Asia   36.088  13079460  739.981106       AFG        4
# ...           ...       ...      ...       ...         ...       ...      ...
# 1987     Zimbabwe    Africa   62.351   9216418  706.157306       ZWE      716
# 1992     Zimbabwe    Africa   60.377  10704340  693.420786       ZWE      716
# 1997     Zimbabwe    Africa   46.809  11404948  792.449960       ZWE      716
# 2002     Zimbabwe    Africa   39.989  11926563  672.038623       ZWE      716
# 2007     Zimbabwe    Africa   43.487  12311143  469.709298       ZWE      716
#
# [1704 rows x 7 columns]

# %%
temp.iloc[1689]
# Out:
# COUNTRY           Zambia
# continent         Africa
# lifeExp           40.238
# pop              9417789
# GDP          1071.353818
# iso_alpha            ZMB
# iso_num              894
# Name: 1997, dtype: object

# %%
temp.loc[[2007]]
# Out:
#                  COUNTRY continent  lifeExp       pop           GDP iso_alpha  \
# year
# 2007         Afghanistan      Asia   43.828  31889923    974.580338       AFG
# 2007             Albania    Europe   76.423   3600523   5937.029526       ALB
# 2007             Algeria    Africa   72.301  33333216   6223.367465       DZA
# 2007              Angola    Africa   42.731  12420476   4797.231267       AGO
# 2007           Argentina  Americas   75.320  40301927  12779.379640       ARG
# ...                  ...       ...      ...       ...           ...       ...
# 2007             Vietnam      Asia   74.249  85262356   2441.576404       VNM
# 2007  West Bank and Gaza      Asia   73.422   4018332   3025.349798       PSE
# 2007         Yemen, Rep.      Asia   62.698  22211743   2280.769906       YEM
# 2007              Zambia    Africa   42.384  11746035   1271.211593       ZMB
# 2007            Zimbabwe    Africa   43.487  12311143    469.709298       ZWE
#
#       iso_num
# year
# ...

# %%
temp.iloc[50:100:1]
# Out:
#          COUNTRY continent  lifeExp       pop           GDP iso_alpha  iso_num
# year
# 1962   Argentina  Americas   65.142  21283783   7133.166023       ARG       32
# 1967   Argentina  Americas   65.634  22934225   8052.953021       ARG       32
# 1972   Argentina  Americas   67.065  24779799   9443.038526       ARG       32
# 1977   Argentina  Americas   68.481  26983828  10079.026740       ARG       32
# 1982   Argentina  Americas   69.942  29341374   8997.897412       ARG       32
# 1987   Argentina  Americas   70.774  31620918   9139.671389       ARG       32
# 1992   Argentina  Americas   71.868  33958947   9308.418710       ARG       32
# 1997   Argentina  Americas   73.275  36203463  10967.281950       ARG       32
# 2002   Argentina  Americas   74.340  38331121   8797.640716       ARG       32
# 2007   Argentina  Americas   75.320  40301927  12779.379640       ARG       32
# 1952   Australia   Oceania   69.120   8691212  10039.595640       AUS       36
# ...

# %% [markdown]
# # df.iloc[row_slicing,columns_slicing]
# # row_slicing:starting index: ending:step

# %%
temp
# Out:
#           COUNTRY continent  lifeExp       pop         GDP iso_alpha  iso_num
# year
# 1952  Afghanistan      Asia   28.801   8425333  779.445314       AFG        4
# 1957  Afghanistan      Asia   30.332   9240934  820.853030       AFG        4
# 1962  Afghanistan      Asia   31.997  10267083  853.100710       AFG        4
# 1967  Afghanistan      Asia   34.020  11537966  836.197138       AFG        4
# 1972  Afghanistan      Asia   36.088  13079460  739.981106       AFG        4
# ...           ...       ...      ...       ...         ...       ...      ...
# 1987     Zimbabwe    Africa   62.351   9216418  706.157306       ZWE      716
# 1992     Zimbabwe    Africa   60.377  10704340  693.420786       ZWE      716
# 1997     Zimbabwe    Africa   46.809  11404948  792.449960       ZWE      716
# 2002     Zimbabwe    Africa   39.989  11926563  672.038623       ZWE      716
# 2007     Zimbabwe    Africa   43.487  12311143  469.709298       ZWE      716
#
# [1704 rows x 7 columns]

# %%
df.iloc[50:100:2,:3]
# Out:
#        COUNTRY continent  year
# 50   Argentina  Americas  1962
# 52   Argentina  Americas  1972
# 54   Argentina  Americas  1982
# 56   Argentina  Americas  1992
# 58   Argentina  Americas  2002
# 60   Australia   Oceania  1952
# 62   Australia   Oceania  1962
# 64   Australia   Oceania  1972
# 66   Australia   Oceania  1982
# 68   Australia   Oceania  1992
# 70   Australia   Oceania  2002
# 72     Austria    Europe  1952
# 74     Austria    Europe  1962
# 76     Austria    Europe  1972
# 78     Austria    Europe  1982
# 80     Austria    Europe  1992
# 82     Austria    Europe  2002
# 84     Bahrain      Asia  1952
# 86     Bahrain      Asia  1962
# 88     Bahrain      Asia  1972
# 90     Bahrain      Asia  1982
# 92     Bahrain      Asia  1992
# 94     Bahrain      Asia  2002
# 96  Bangladesh      Asia  1952
# 98  Bangladesh      Asia  1962

# %% [markdown]
# # loc

# %%
temp.reset_index()
# Out:
#       year      COUNTRY continent  lifeExp       pop         GDP iso_alpha  \
# 0     1952  Afghanistan      Asia   28.801   8425333  779.445314       AFG
# 1     1957  Afghanistan      Asia   30.332   9240934  820.853030       AFG
# 2     1962  Afghanistan      Asia   31.997  10267083  853.100710       AFG
# 3     1967  Afghanistan      Asia   34.020  11537966  836.197138       AFG
# 4     1972  Afghanistan      Asia   36.088  13079460  739.981106       AFG
# ...    ...          ...       ...      ...       ...         ...       ...
# 1699  1987     Zimbabwe    Africa   62.351   9216418  706.157306       ZWE
# 1700  1992     Zimbabwe    Africa   60.377  10704340  693.420786       ZWE
# 1701  1997     Zimbabwe    Africa   46.809  11404948  792.449960       ZWE
# 1702  2002     Zimbabwe    Africa   39.989  11926563  672.038623       ZWE
# 1703  2007     Zimbabwe    Africa   43.487  12311143  469.709298       ZWE
#
#       iso_num
# 0           4
# 1           4
# 2           4
# ...

# %%
temp=temp.set_index('continent')

# %%
temp.loc[['Asia','Africa'],['COUNTRY','pop']]
# Out:
#                COUNTRY       pop
# continent
# Asia       Afghanistan   8425333
# Asia       Afghanistan   9240934
# Asia       Afghanistan  10267083
# Asia       Afghanistan  11537966
# Asia       Afghanistan  13079460
# ...                ...       ...
# Africa        Zimbabwe   9216418
# Africa        Zimbabwe  10704340
# Africa        Zimbabwe  11404948
# Africa        Zimbabwe  11926563
# Africa        Zimbabwe  12311143
#
# [1020 rows x 2 columns]

# %%
temp.iloc[0:100:5,:3]
# Out:
#                COUNTRY  lifeExp       pop
# continent
# Asia       Afghanistan   28.801   8425333
# Asia       Afghanistan   38.438  14880372
# Asia       Afghanistan   42.129  25268405
# Europe         Albania   66.220   1984060
# Europe         Albania   71.581   3326498
# Africa         Algeria   45.685  10270856
# Africa         Algeria   61.368  20033753
# Africa         Algeria   72.301  33333216
# Africa          Angola   37.928   5894858
# Africa          Angola   40.963   9875024
# Americas     Argentina   65.142  21283783
# Americas     Argentina   70.774  31620918
# Oceania      Australia   69.120   8691212
# Oceania      Australia   73.490  14074100
# Oceania      Australia   80.370  19546792
# Europe         Austria   70.140   7376998
# Europe         Austria   76.040   7914969
# Asia           Bahrain   53.832    138655
# Asia           Bahrain   69.052    377967
# Asia           Bahrain   75.635    708573

# %% [markdown]
# # nlargest, n smallest

# %%
df
# Out:
#           COUNTRY continent  year  lifeExp       pop         GDP iso_alpha  \
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
# ...           ...       ...   ...      ...       ...         ...       ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306       ZWE
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786       ZWE
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960       ZWE
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623       ZWE
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298       ZWE
#
#       iso_num
# 0           4
# 1           4
# 2           4
# ...

# %%
df.nlargest(5,'lifeExp')
# Out:
#                COUNTRY continent  year  lifeExp        pop          GDP  \
# 803              Japan      Asia  2007   82.603  127467972  31656.06806
# 671   Hong Kong, China      Asia  2007   82.208    6980412  39724.97867
# 802              Japan      Asia  2002   82.000  127065841  28604.59190
# 695            Iceland    Europe  2007   81.757     301931  36180.78919
# 1487       Switzerland    Europe  2007   81.701    7554661  37506.41907
#
#      iso_alpha  iso_num
# 803        JPN      392
# 671        HKG      344
# 802        JPN      392
# 695        ISL      352
# 1487       CHE      756

# %%
df.nlargest(5,'pop')
# Out:
#     COUNTRY continent  year  lifeExp         pop          GDP iso_alpha  \
# 299   China      Asia  2007   72.961  1318683096  4959.114854       CHN
# 298   China      Asia  2002   72.028  1280400000  3119.280896       CHN
# 297   China      Asia  1997   70.426  1230075000  2289.234136       CHN
# 296   China      Asia  1992   68.690  1164970000  1655.784158       CHN
# 707   India      Asia  2007   64.698  1110396331  2452.210407       IND
#
#      iso_num
# 299      156
# 298      156
# 297      156
# 296      156
# 707      356

# %%
df.nsmallest(10,'pop')
# Out:
#                     COUNTRY continent  year  lifeExp    pop          GDP  \
# 1296  Sao Tome and Principe    Africa  1952   46.471  60011   879.583586
# 1297  Sao Tome and Principe    Africa  1957   48.945  61325   860.736903
# 420                Djibouti    Africa  1952   34.812  63149  2669.529475
# 1298  Sao Tome and Principe    Africa  1962   51.893  65345  1071.551119
# 1299  Sao Tome and Principe    Africa  1967   54.425  70787  1384.840593
# 421                Djibouti    Africa  1957   37.328  71851  2864.969076
# 1300  Sao Tome and Principe    Africa  1972   56.480  76595  1532.985254
# 1301  Sao Tome and Principe    Africa  1977   58.550  86796  1737.561657
# 422                Djibouti    Africa  1962   39.693  89898  3020.989263
# 1302  Sao Tome and Principe    Africa  1982   60.351  98593  1890.218117
#
#      iso_alpha  iso_num
# 1296       STP      678
# 1297       STP      678
# 420        DJI      262
# 1298       STP      678
# 1299       STP      678
# ...

# %% [markdown]
# ## sort methods

# %%
dfs=pd.read_csv(r'E:\New folder\movies.csv')
dfs
# Out:
#                            Series_Title  Released_Year  Runtime   Genre  \
# 0                             Chinatown           1974      130   Drama
# 1       The Girl with the Dragon Tattoo           2011      158   Crime
# 2                          Nueve reinas           2000      114   Crime
# 3    Close Encounters of the Third Kind           1977      138   Drama
# 4                                 Joker           2019      122   Crime
# ..                                  ...            ...      ...     ...
# 295                         Kumonosu-jô           1957      110   Drama
# 296                        Falling Down           1993      113  Action
# 297                The Royal Tenenbaums           2001      110  Comedy
# 298                     Midnight Cowboy           1969      113   Drama
# 299                         Kai po che!           2013      130   Drama
#
#      IMDB_Rating          Director             Star1  No_of_Votes  \
# ...

# %%
dfs.sort_values('Series_Title')
# Out:
#                         Series_Title  Released_Year  Runtime      Genre  \
# 111                 28 Days Later...           2002      113      Drama
# 265                               8½           1963      138      Drama
# 101                 A Beautiful Mind           2001      135  Biography
# 235                     A Bronx Tale           1993      121      Crime
# 62                A Clockwork Orange           1971      136      Crime
# ..                               ...            ...      ...        ...
# 171  Who's Afraid of Virginia Woolf?           1966      131      Drama
# 242                           Wonder           2017      113      Drama
# 137       X-Men: Days of Future Past           2014      132     Action
# 155                          Zerkalo           1975      107  Biography
# 114         Zindagi Na Milegi Dobara           2011      155     Comedy
#
#      IMDB_Rating          Director                 Star1  No_of_Votes  \
# ...

# %%
dfs.sort_values(['Genre','IMDB_Rating'],ascending=[True,False])
# Out:
#                      Series_Title  Released_Year  Runtime      Genre  \
# 129               The Dark Knight           2008      152     Action
# 77                     The Matrix           1999      136     Action
# 180          Shichinin no samurai           1954      207     Action
# 104    Terminator 2: Judgment Day           1991      137     Action
# 190         The Dark Knight Rises           2012      164     Action
# ..                            ...            ...      ...        ...
# 29                  The Third Man           1949      104  Film-Noir
# 75                  The Innocents           1961      100     Horror
# 156                           Saw           2004      103     Horror
# 94                      Dark City           1998      100    Mystery
# 195  Once Upon a Time in the West           1968      165    Western
#
#      IMDB_Rating           Director                  Star1  No_of_Votes  \
# ...

# %%
pd.reset_option('display.max_rows',None)

# %%
dfs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Series_Title   300 non-null    object
#  1   Released_Year  300 non-null    int64
#  2   Runtime        300 non-null    int64
#  3   Genre          300 non-null    object
#  4   IMDB_Rating    300 non-null    float64
#  5   Director       300 non-null    object
#  6   Star1          300 non-null    object
#  7   No_of_Votes    300 non-null    int64
#  8   Gross          300 non-null    float64
#  9   Metascore      264 non-null    float64
# dtypes: float64(3), int64(3), object(4)
# memory usage: 23.6+ KB

# %%
dfs['Series_Title'].str.swapcase()
# Out:
# 0                               cHINATOWN
# 1         tHE gIRL WITH THE dRAGON tATTOO
# 2                            nUEVE REINAS
# 3      cLOSE eNCOUNTERS OF THE tHIRD kIND
# 4                                   jOKER
#                       ...
# 295                           kUMONOSU-JÔ
# 296                          fALLING dOWN
# 297                  tHE rOYAL tENENBAUMS
# 298                       mIDNIGHT cOWBOY
# 299                           kAI PO CHE!
# Name: Series_Title, Length: 300, dtype: object

# %%
dfs['Series_Title']=dfs['Series_Title'].str.lower()
dfs
# Out:
#                            Series_Title  Released_Year  Runtime   Genre  \
# 0                             chinatown           1974      130   Drama
# 1       the girl with the dragon tattoo           2011      158   Crime
# 2                          nueve reinas           2000      114   Crime
# 3    close encounters of the third kind           1977      138   Drama
# 4                                 joker           2019      122   Crime
# ..                                  ...            ...      ...     ...
# 295                         kumonosu-jô           1957      110   Drama
# 296                        falling down           1993      113  Action
# 297                the royal tenenbaums           2001      110  Comedy
# 298                     midnight cowboy           1969      113   Drama
# 299                         kai po che!           2013      130   Drama
#
#      IMDB_Rating          Director             Star1  No_of_Votes  \
# ...

# %%
dfs['Series_Title']=dfs['Series_Title'].str.upper()
dfs['swapcase']=dfs['Series_Title'].str.lower()

# %%
dfs
# Out:
#                            Series_Title  Released_Year  Runtime   Genre  \
# 0                             CHINATOWN           1974      130   Drama
# 1       THE GIRL WITH THE DRAGON TATTOO           2011      158   Crime
# 2                          NUEVE REINAS           2000      114   Crime
# 3    CLOSE ENCOUNTERS OF THE THIRD KIND           1977      138   Drama
# 4                                 JOKER           2019      122   Crime
# ..                                  ...            ...      ...     ...
# 295                         KUMONOSU-JÔ           1957      110   Drama
# 296                        FALLING DOWN           1993      113  Action
# 297                THE ROYAL TENENBAUMS           2001      110  Comedy
# 298                     MIDNIGHT COWBOY           1969      113   Drama
# 299                         KAI PO CHE!           2013      130   Drama
#
#      IMDB_Rating          Director             Star1  No_of_Votes  \
# ...
