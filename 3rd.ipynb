# %%
import numpy as np

# %% [markdown]
# ## indexing and slicing

# %%
arr1d=np.random.randint(1,100,10)
arr1d
# Out:
# array([99, 99, 45, 69,  1, 16, 96, 20, 26,  7])

# %%
print(arr1d[0])
print(arr1d[1])
print(arr1d[-1])
print(arr1d[-2])
# Out:
# 99
# 99
# 7
# 26

# %%
arr1d[1:5]
# Out:
# array([99, 45, 69,  1])

# %%
arr1d[-1:-3:-1]
# Out:
# array([ 7, 26])

# %%
arr1d[-3::1]
# Out:
# array([20, 26,  7])

# %%
arr1d[-1:-5:-1]
# Out:
# array([ 7, 26, 20, 96])

# %% [markdown]
# ### indexing and slicing in 2d array

# %%
arr2d=np.random.randint(1,200,size=(5,4))
arr2d
# Out:
# array([[ 27,  51, 121, 194],
#        [179,  98,  76, 197],
#        [157,  67, 135, 160],
#        [139, 195, 134, 188],
#        [179, 102,  53,  90]])

# %%
arr2d[0]
# Out:
# array([ 27,  51, 121, 194])

# %%
arr2d[3][2]
# Out:
# 134

# %%
arr2d[-4][-3]
# Out:
# 98

# %% [markdown]
# # slicing in 2d array

# %%
arr2d
# Out:
# array([[ 27,  51, 121, 194],
#        [179,  98,  76, 197],
#        [157,  67, 135, 160],
#        [139, 195, 134, 188],
#        [179, 102,  53,  90]])

# %%
# arr2d[row_slicing , column_slicing]
# row-slicing:[start:ending:step]
# column-slicing:[start:ending:step]

# %%
arr2d[:,:]
# Out:
# array([[ 27,  51, 121, 194],
#        [179,  98,  76, 197],
#        [157,  67, 135, 160],
#        [139, 195, 134, 188],
#        [179, 102,  53,  90]])

# %%
arr2d[0:2,:]
# Out:
# array([[ 27,  51, 121, 194],
#        [179,  98,  76, 197]])

# %%
arr2d[:,0:2]
# Out:
# array([[ 27,  51],
#        [179,  98],
#        [157,  67],
#        [139, 195],
#        [179, 102]])

# %%
arr2d[::2,:]
# Out:
# array([[ 27,  51, 121, 194],
#        [157,  67, 135, 160],
#        [179, 102,  53,  90]])

# %%
arr2d[::,::-1]
# Out:
# array([[194, 121,  51,  27],
#        [197,  76,  98, 179],
#        [160, 135,  67, 157],
#        [188, 134, 195, 139],
#        [ 90,  53, 102, 179]])

# %%
arr2d[-2::,:]
# Out:
# array([[139, 195, 134, 188],
#        [179, 102,  53,  90]])

# %%
arr2d[-2::,2:]
# Out:
# array([[134, 188],
#        [ 53,  90]])

# %%
arr2d
# Out:
# array([[ 27,  51, 121, 194],
#        [179,  98,  76, 197],
#        [157,  67, 135, 160],
#        [139, 195, 134, 188],
#        [179, 102,  53,  90]])

# %%
arr2d[1:3,1:3]
# Out:
# array([[ 98,  76],
#        [ 67, 135]])

# %%
arr2d[0:5:4,0:4:3]
# Out:
# array([[ 27, 194],
#        [179,  90]])

# %%
arr2d.shape
# Out:
# (5, 4)

# %%
def extract_corner(array):
    print(array)
    print()
    n_row,n_col=array.shape
    return array[::n_row-1,::n_col-1]

# %%
extract_corner(np.random.randint(1,100,size=(4,7)))
# Out:
# [[69 64 50 93 20 13 22]
#  [81 35 98  6 78 29 51]
#  [97 14 83 24 25 69 61]
#  [21 56 85 23 84 46 80]]
# array([[69, 22],
#        [21, 80]])

# %%
arr2d
# Out:
# array([[ 27,  51, 121, 194],
#        [179,  98,  76, 197],
#        [157,  67, 135, 160],
#        [139, 195, 134, 188],
#        [179, 102,  53,  90]])

# %%
arr2d[::-1,::-1]
# Out:
# array([[ 90,  53, 102, 179],
#        [188, 134, 195, 139],
#        [160, 135,  67, 157],
#        [197,  76,  98, 179],
#        [194, 121,  51,  27]])

# %%
arr2d.ndim
# Out:
# 2

# %%
arr2d
# Out:
# array([[ 27,  51, 121, 194],
#        [179,  98,  76, 197],
#        [157,  67, 135, 160],
#        [139, 195, 134, 188],
#        [179, 102,  53,  90]])

# %%
n_row,n_col=arr2d.shape

n_row
# Out:
# 5
