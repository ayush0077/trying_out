# %%
import pandas as pd

# %%
id_=[1,2,3,4,5]
name=['ram','shyam','hari','gopal','suresh']
age=[20,30,40,50,60]
salary=[1000,2000,3000,3400,5000]
location=['kathmandu','bhaktapur','lalitpur','dhangadi','parbat']

dicts={'id':id_,'Name': name, 'Age': age, 'Salary': salary, 'Address': location}
dicts
# Out:
# {'id': [1, 2, 3, 4, 5],
#  'Name': ['ram', 'shyam', 'hari', 'gopal', 'suresh'],
#  'Age': [20, 30, 40, 50, 60],
#  'Salary': [1000, 2000, 3000, 3400, 5000],
#  'Address': ['kathmandu', 'bhaktapur', 'lalitpur', 'dhangadi', 'parbat']}

# %%
df=pd.DataFrame(dicts)
df
# Out:
#    id    Name  Age  Salary    Address
# 0   1     ram   20    1000  kathmandu
# 1   2   shyam   30    2000  bhaktapur
# 2   3    hari   40    3000   lalitpur
# 3   4   gopal   50    3400   dhangadi
# 4   5  suresh   60    5000     parbat

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# # export into different file formats

# %%
df.to_csv(r'D:\New folder\New folder\data1.csv',index=False)

# %% [markdown]
# # Export into json file

# %%
df.to_json(r'D:\New folder\New folder\data1.json',orient="records",indent=4)

# %% [markdown]
# ## export into excel file

# %%
# !pip install openpyxl
# Out:
# ...
#    ---------------------------------------- 0.0/250.9 kB ? eta -:--:--
#    ------ -------------------------------- 41.0/250.9 kB 991.0 kB/s eta 0:00:01
#    --------------------------- ------------ 174.1/250.9 kB 2.1 MB/s eta 0:00:01
#    ---------------------------------------- 250.9/250.9 kB 2.2 MB/s eta 0:00:00
# ...
# [notice] A new release of pip is available: 24.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
with pd.ExcelWriter(r'D:\New folder\New folder\excel.xlsx',engine='openpyxl') as writer:
    df.to_excel(writer,sheet_name="data1",index=False)
    dfs.to_excel(writer,sheet_name="data2",index=False)

# %%
dfs=pd.DataFrame({'name':['ram','shyam'],'age':[20,30]})
dfs
# Out:
#     name  age
# 0    ram   20
# 1  shyam   30

# %% [markdown]
# # Readina a csv and json

# %%
pd.read_csv(r'D:\New folder\New folder\data1.csv')
# Out:
#    id    Name  Age  Salary    Address
# 0   1     ram   20    1000  kathmandu
# 1   2   shyam   30    2000  bhaktapur
# 2   3    hari   40    3000   lalitpur
# 3   4   gopal   50    3400   dhangadi
# 4   5  suresh   60    5000     parbat

# %% [markdown]
#  # important attribute

# %%
import numpy as np

# %%
df.shape
# Out:
# (5, 5)

# %%
np.shape(dfs)
# Out:
# (2, 2)

# %%
np.shape(df)
# Out:
# (5, 5)

# %% [markdown]
# # string: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       5 non-null      int64
#  1   Name     5 non-null      object
#  2   Age      5 non-null      int64
#  3   Salary   5 non-null      int64
#  4   Address  5 non-null      object
# dtypes: int64(3), object(2)
# memory usage: 328.0+ bytes

# %%
df.columns
# Out:
# Index(['id', 'Name', 'Age', 'Salary', 'Address'], dtype='object')
