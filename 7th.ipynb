# %% [markdown]
# ## Matrix Transpose

# %%
import numpy as np

# %%
arr=np.random.randint(1,100,size=(4,5))
arr
# Out:
# array([[52, 61, 89, 49,  6],
#        [49, 49, 60, 80,  2],
#        [39, 84, 22, 29, 27],
#        [75,  7, 69, 56, 30]])

# %%
arr.shape
# Out:
# (4, 5)

# %%
np.transpose(arr)
# Out:
# array([[52, 49, 39, 75],
#        [61, 49, 84,  7],
#        [89, 60, 22, 69],
#        [49, 80, 29, 56],
#        [ 6,  2, 27, 30]])

# %%
type(arr)
# Out:
# numpy.ndarray

# %% [markdown]
# ## Dot products

# %%
arr1=np.random.randint(1,100,size=(4,5))
arr2=np.random.randint(1,100,size=(5,3))

# %%
np.dot(arr1,arr2)
# Out:
# array([[ 5822,  6746,  4591],
#        [13049, 12109, 19083],
#        [11974,  8894, 17880],
#        [14586, 11339, 14782]])

# %%
arr
# Out:
# array([[52, 61, 89, 49,  6],
#        [49, 49, 60, 80,  2],
#        [39, 84, 22, 29, 27],
#        [75,  7, 69, 56, 30]])

# %%
arr=np.random.randint(1,100,size=(4,2))
arr
# Out:
# array([[50, 20],
#        [36, 47],
#        [72, 68],
#        [ 7, 39]])

# %%
np.vsplit(arr,2)
# Out:
# [array([[50, 20],
#         [36, 47]]),
#  array([[72, 68],
#         [ 7, 39]])]

# %%
type(np.vsplit(arr,2))
# Out:
# list

# %%
arr1=np.random.randint(1,100,size=(8,5))
arr1
# Out:
# array([[66, 56, 17, 93, 68],
#        [91, 18, 16, 95, 73],
#        [37, 44, 26, 65, 99],
#        [ 2, 10, 60, 42, 86],
#        [47, 60, 81, 55, 55],
#        [ 9, 20,  2, 79, 46],
#        [55, 85, 50, 84, 87],
#        [94, 83, 71,  6, 41]])

# %%
arr2=np.random.randint(1,100,size=(8,5))
arr2
# Out:
# array([[10, 13, 55, 58, 26],
#        [60, 81, 81, 12, 60],
#        [19,  8, 85, 96, 68],
#        [46,  5, 80, 54, 22],
#        [96, 74, 18, 77, 66],
#        [79, 15,  8, 90, 11],
#        [35, 49, 67, 48, 64],
#        [47, 67, 59, 58, 63]])

# %%
np.concatenate([arr1,arr2])
# Out:
# array([[66, 56, 17, 93, 68],
#        [91, 18, 16, 95, 73],
#        [37, 44, 26, 65, 99],
#        [ 2, 10, 60, 42, 86],
#        [47, 60, 81, 55, 55],
#        [ 9, 20,  2, 79, 46],
#        [55, 85, 50, 84, 87],
#        [94, 83, 71,  6, 41],
#        [10, 13, 55, 58, 26],
#        [60, 81, 81, 12, 60],
#        [19,  8, 85, 96, 68],
#        [46,  5, 80, 54, 22],
#        [96, 74, 18, 77, 66],
#        [79, 15,  8, 90, 11],
#        [35, 49, 67, 48, 64],
#        [47, 67, 59, 58, 63]])

# %%
X=np.linspace(-10,10,40)
X
# Out:
# array([-10.        ,  -9.48717949,  -8.97435897,  -8.46153846,
#         -7.94871795,  -7.43589744,  -6.92307692,  -6.41025641,
#         -5.8974359 ,  -5.38461538,  -4.87179487,  -4.35897436,
#         -3.84615385,  -3.33333333,  -2.82051282,  -2.30769231,
#         -1.79487179,  -1.28205128,  -0.76923077,  -0.25641026,
#          0.25641026,   0.76923077,   1.28205128,   1.79487179,
#          2.30769231,   2.82051282,   3.33333333,   3.84615385,
#          4.35897436,   4.87179487,   5.38461538,   5.8974359 ,
#          6.41025641,   6.92307692,   7.43589744,   7.94871795,
#          8.46153846,   8.97435897,   9.48717949,  10.        ])

# %%
Y=X**2
Y
# Out:
# array([1.00000000e+02, 9.00065746e+01, 8.05391190e+01, 7.15976331e+01,
#        6.31821170e+01, 5.52925707e+01, 4.79289941e+01, 4.10913872e+01,
#        3.47797502e+01, 2.89940828e+01, 2.37343853e+01, 1.90006575e+01,
#        1.47928994e+01, 1.11111111e+01, 7.95529257e+00, 5.32544379e+00,
#        3.22156476e+00, 1.64365549e+00, 5.91715976e-01, 6.57462196e-02,
#        6.57462196e-02, 5.91715976e-01, 1.64365549e+00, 3.22156476e+00,
#        5.32544379e+00, 7.95529257e+00, 1.11111111e+01, 1.47928994e+01,
#        1.90006575e+01, 2.37343853e+01, 2.89940828e+01, 3.47797502e+01,
#        4.10913872e+01, 4.79289941e+01, 5.52925707e+01, 6.31821170e+01,
#        7.15976331e+01, 8.05391190e+01, 9.00065746e+01, 1.00000000e+02])

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(X,Y)

# %%
plt.plot(X,Y)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
X=np.linspace(-10,10,40)
X
y=np.sin(X)

# %%
plt.plot(y)
