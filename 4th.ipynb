# %% [markdown]
# # 3d array

# %%
import numpy as np

# %%
# arr2d[2d_slicing: row_slicing:column_slicing]
# 2d_slicing: start :end :step

# %%
arr3d=np.random.randint(1,100,size=(3,4,5))
arr3d
# Out:
# array([[[ 6, 26,  2, 23, 23],
#         [96,  1, 89, 68, 44],
#         [32, 25, 60, 39, 63],
#         [74, 47,  6,  7, 57]],
#
#        [[32, 82, 79, 96, 95],
#         [29, 62, 60, 82, 16],
#         [26, 70, 61, 78, 36],
#         [74, 46, 39, 61, 93]],
#
#        [[32, 98, 20, 12, 94],
#         [49, 96, 54, 57, 47],
#         [ 4, 78, 60, 18,  9],
#         [84, 59, 21, 80, 54]]])

# %%
arr3d[0][2][3]
# Out:
# 39

# %% [raw]
# arr3d[0,1]
# arr3d

# %%
arr3d[0:3:2,2:4,2:4]
# Out:
# array([[[60, 39],
#         [ 6,  7]],
#
#        [[60, 18],
#         [21, 80]]])

# %%
lists=['name','age','salary','ram',20,3000,'shyam',22,44000,'hari',12,6000,'ramesh',34,40000]
lists
# Out:
# ['name',
#  'age',
#  'salary',
#  'ram',
#  20,
#  3000,
#  'shyam',
#  22,
#  44000,
#  'hari',
#  12,
#  6000,
#  'ramesh',
#  34,
#  40000]

# %%
arr=np.array(lists)
arr
arr.type
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[69], line 3
#       1 arr=np.array(lists)
#       2 arr
# ----> 3 arr.type
#
# AttributeError: 'numpy.ndarray' object has no attribute 'type'

# %%
arr.ndim
# Out:
# 1

# %%
arr.size
# Out:
# 15

# %%
arr.size/3
# Out:
# 5.0

# %%
arr.reshape(5,3)
# Out:
# array([['name', 'age', 'salary'],
#        ['ram', '20', '3000'],
#        ['shyam', '22', '44000'],
#        ['hari', '12', '6000'],
#        ['ramesh', '34', '40000']], dtype='<U11')

# %%
import pandas as pd

# %%
df=pd.DataFrame(arr.reshape(5,3))
df
# Out:
#         0    1       2
# 0    name  age  salary
# 1     ram   20    3000
# 2   shyam   22   44000
# 3    hari   12    6000
# 4  ramesh   34   40000

# %% [markdown]
# ## flaten(),ravel()

# %%
np.random.randint(1,100,size=(3,4,5))
# Out:
# array([[[14, 63, 98, 90, 93],
#         [33, 11, 98, 29, 49],
#         [13, 74, 48, 36, 48],
#         [37, 53, 30, 63, 80]],
#
#        [[74, 99, 95, 63, 28],
#         [ 5, 83, 90, 73, 27],
#         [37, 59,  8, 14, 28],
#         [52, 64,  7, 46, 13]],
#
#        [[ 6, 20, 83, 60, 81],
#         [ 4,  3, 91, 90, 37],
#         [21, 89, 34, 22, 22],
#         [ 2,  9, 80, 47,  1]]])

# %%
arr3d.ravel()
# Out:
# array([54, 23, 87, 37, 79, 40, 81, 61, 65, 75, 89, 15, 24, 73, 80, 97, 99,
#        28, 93, 22, 12, 73, 81, 65, 98, 72, 20,  1, 44, 67, 95, 23, 40, 50,
#        17, 68,  4,  3, 89, 31, 50, 10, 24,  2, 47, 50, 70, 57, 63, 28, 25,
#        20, 58, 73,  8, 58, 57, 55, 96, 62])

# %%
arr3d.flatten()
# Out:
# array([54, 23, 87, 37, 79, 40, 81, 61, 65, 75, 89, 15, 24, 73, 80, 97, 99,
#        28, 93, 22, 12, 73, 81, 65, 98, 72, 20,  1, 44, 67, 95, 23, 40, 50,
#        17, 68,  4,  3, 89, 31, 50, 10, 24,  2, 47, 50, 70, 57, 63, 28, 25,
#        20, 58, 73,  8, 58, 57, 55, 96, 62])

# %%
arr3d.flatten().shape
# Out:
# (60,)

# %% [markdown]
# # operatpr in array

# %%
arr=np.random.randint(1,100,10)
arr
# Out:
# array([ 7, 45, 79, 95, 68, 18, 69, 38, 72, 96])

# %%
arr+10
# Out:
# array([ 17,  55,  89, 105,  78,  28,  79,  48,  82, 106])

# %% [markdown]
# # Vector Operation

# %%
arr2=np.random.randint(1,100,10)
arr2
# Out:
# array([80, 32, 81, 51, 27,  3, 58, 89, 59, 35])

# %%
 arr2d1=np.random.randint(1,100,size=(4,5))
 arr2d2=np.random.randint(1,100,size=(4,5))

# %%
arr2d1
# Out:
# array([[32, 21, 22, 21, 35],
#        [92,  8,  8, 94, 31],
#        [99, 96, 28, 83,  8],
#        [52,  4, 86, 99, 88]])

# %%
arr2d2
# Out:
# array([[81, 39, 30, 80, 77],
#        [ 3, 55,  8, 14, 18],
#        [42, 96, 76, 39, 71],
#        [62,  8, 94, 11, 95]])

# %%
arr3d1=np.random.randint(1,100,size=(3,4,5))
arr3d1
# Out:
# array([[[58, 14, 68,  6, 47],
#         [72, 94, 22,  5, 10],
#         [64, 26, 35, 87, 14],
#         [28,  3, 97, 70, 93]],
#
#        [[49, 39, 57, 53, 20],
#         [84, 64, 91, 22, 84],
#         [88, 62, 12, 62, 56],
#         [14, 51, 96, 61, 14]],
#
#        [[36, 81, 90, 55, 85],
#         [27,  9,  6, 97, 80],
#         [17, 68, 37, 24, 22],
#         [19, 68, 79,  4, 69]]])

# %%
arr3d2=np.random.randint(1,100,size=(3,4,5))
arr3d2
# Out:
# array([[[ 6, 92, 70, 24, 53],
#         [21, 53, 63, 90, 89],
#         [64, 92, 41, 87, 49],
#         [40, 34, 87, 92, 91]],
#
#        [[37, 10, 28, 73, 85],
#         [61, 48, 88, 15, 14],
#         [10,  1, 90, 28, 91],
#         [45, 16, 31, 80, 34]],
#
#        [[75, 68, 29, 98,  3],
#         [50, 81, 93, 12,  9],
#         [12, 33, 61, 30, 24],
#         [14, 18, 68, 50, 65]]])

# %%
arr3d1-arr3d2
# Out:
# array([[[ 39, -25,  34, -41, -42],
#         [-52,  12, -53,  45, -35],
#         [ 48, -28,  -4,   6,  65],
#         [-54,  14,  21,   1,  15]],
#
#        [[-16,  94,  29,  49, -52],
#         [ 31,   4,  -8, -67,  24],
#         [-13,   9,  -9,   9,   1],
#         [ 19,  18, -62, -12,  58]],
#
#        [[ 19,  53,  44,  31,  32],
#         [ 64, -37,  75, -38,  20],
#         [ 56,  -1,  25,  29, -22],
#         [  0,  -3, -11,   6,  56]]])

# %%
arr3d1.mean()
# Out:
# 49.416666666666664

# %%
(arr3d1-arr3d1.mean())**2
# Out:
# array([[[7.36736111e+01, 1.25434028e+03, 3.45340278e+02, 1.88500694e+03,
#          5.84027778e+00],
#         [5.10006944e+02, 1.98767361e+03, 7.51673611e+02, 1.97284028e+03,
#          1.55367361e+03],
#         [2.12673611e+02, 5.48340278e+02, 2.07840278e+02, 1.41250694e+03,
#          1.25434028e+03],
#         [4.58673611e+02, 2.15450694e+03, 2.26417361e+03, 4.23673611e+02,
#          1.89950694e+03]],
#
#        [[1.73611111e-01, 1.08506944e+02, 5.75069444e+01, 1.28402778e+01,
#          8.65340278e+02],
#         [1.19600694e+03, 2.12673611e+02, 1.72917361e+03, 7.51673611e+02,
#          1.19600694e+03],
#         [1.48867361e+03, 1.58340278e+02, 1.40000694e+03, 1.58340278e+02,
#          4.33402778e+01],
#         [1.25434028e+03, 2.50694444e+00, 2.17000694e+03, 1.34173611e+02,
#          1.25434028e+03]],
#
#        [[1.80006944e+02, 9.97506944e+02, 1.64700694e+03, 3.11736111e+01,
#          1.26617361e+03],
# ...

# %%
l1=[10,20,30,40]
def standard_array(l1):
    arr=np.array(l1)
    return (np.sum((arr-arr.mean())**2)/(len(arr)-1))**0.5
l1 
standard_array(l1)
# Out:
# 12.909944487358056
