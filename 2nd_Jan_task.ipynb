# %%
import pandas as pd
# Out:
# C:\Users\Ryzen\AppData\Local\Temp\ipykernel_21132\4080736814.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
students=pd.read_csv(r'E:\Datascience\dataset\New folder\students.csv')
nov=pd.read_csv(r'E:\Datascience\dataset\New folder\reg-month1.csv')
dec=pd.read_csv(r'E:\Datascience\dataset\New folder\reg-month2.csv')
courses=pd.read_csv(r'E:\Datascience\dataset\New folder\courses.csv')

# %%
courses
# Out:
#     course_id       course_name  price
# 0           1            python   2499
# 1           2               sql   3499
# 2           3     data analysis   4999
# 3           4  machine learning   9999
# 4           5           tableau   2499
# 5           6          power bi   1899
# 6           7          ms sxcel   1599
# 7           8            pandas   1099
# 8           9            plotly    699
# 9          10           pyspark   2499
# 10         11             Numpy    699
# 11         12               C++   1299

# %%
dec
# Out:
#     student_id  course_id
# 0            3          5
# 1           16          7
# 2           12         10
# 3           12          1
# 4           14          9
# 5            7          7
# 6            7          2
# 7           16          3
# 8           17         10
# 9           11          8
# 10          14          6
# 11          12          5
# 12          12          7
# 13          18          8
# 14           1         10
# 15           1          9
# 16           2          5
# 17           7          6
# 18          22          5
# 19          22          6
# 20          23          9
# 21          23          5
# 22          14          4
# 23          14          1
# 24          11         10
# 25          42          9
# 26          50          8
# 27          38          1

# %%
asd=pd.merge(dec,courses,how='left',on='course_id')
asd
# Out:
#     student_id  course_id       course_name  price
# 0            3          5           tableau   2499
# 1           16          7          ms sxcel   1599
# 2           12         10           pyspark   2499
# 3           12          1            python   2499
# 4           14          9            plotly    699
# 5            7          7          ms sxcel   1599
# 6            7          2               sql   3499
# 7           16          3     data analysis   4999
# 8           17         10           pyspark   2499
# 9           11          8            pandas   1099
# 10          14          6          power bi   1899
# 11          12          5           tableau   2499
# 12          12          7          ms sxcel   1599
# 13          18          8            pandas   1099
# 14           1         10           pyspark   2499
# 15           1          9            plotly    699
# 16           2          5           tableau   2499
# ...

# %%
asd.groupby('course_name')['price'].sum().plot(kind='bar')
# Out:
# <Axes: xlabel='course_name'>

# %%
asf=pd.merge(nov,courses,how='left',on='course_id')
asf.groupby('course_name')['price'].sum()
# Out:
# course_name
# data analysis       19996
# machine learning    29997
# ms sxcel             3198
# pandas               1099
# plotly                699
# power bi             5697
# pyspark              4998
# python              14994
# sql                  3499
# tableau              4998
# Name: price, dtype: int64

# %%
asf
# Out:
#     student_id  course_id       course_name  price
# 0           23          1            python   2499
# 1           15          5           tableau   2499
# 2           18          6          power bi   1899
# 3           23          4  machine learning   9999
# 4           16          9            plotly    699
# 5           18          1            python   2499
# 6            1          1            python   2499
# 7            7          8            pandas   1099
# 8           22          3     data analysis   4999
# 9           15          1            python   2499
# 10          19          4  machine learning   9999
# 11           1          6          power bi   1899
# 12           7         10           pyspark   2499
# 13          11          7          ms sxcel   1599
# 14          13          3     data analysis   4999
# 15          24          4  machine learning   9999
# 16          21          1            python   2499
# ...

# %% [markdown]
# # Find The Most demand Course ( higher frequency of persons join the  same course is most demanding)

# %%
courses
# Out:
#     course_id       course_name  price
# 0           1            python   2499
# 1           2               sql   3499
# 2           3     data analysis   4999
# 3           4  machine learning   9999
# 4           5           tableau   2499
# 5           6          power bi   1899
# 6           7          ms sxcel   1599
# 7           8            pandas   1099
# 8           9            plotly    699
# 9          10           pyspark   2499
# 10         11             Numpy    699
# 11         12               C++   1299

# %%
students
# Out:
#     student_id                name  partner
# 0            1       Kailash Harjo       23
# 1            2         Esha Butala        1
# 2            3      Parveen Bhalla        3
# 3            4         Marlo Dugal       14
# 4            5         Kusum Bahri        6
# 5            6  Lakshmi Contractor       10
# 6            7        Tarun Thaker        9
# 7            8      Radheshyam Dey        5
# 8            9   Nitika Chatterjee        4
# 9           10      Aayushman Sant        8
# 10          11  David Mukhopadhyay       20
# 11          12          Radha Dutt       19
# 12          13      Munni Varghese       24
# 13          14    Pranab Natarajan       22
# 14          15           Preet Sha       16
# 15          16        Elias Dodiya       25
# 16          17        Yasmin Palan        7
# 17          18     Fardeen Mahabir       13
# 18          19        Qabeel Raman       12
# 19          20       Hanuman Hegde       11
# ...

# %%
temp=pd.concat([nov,dec],ignore_index=False,keys=['november','december']).reset_index()
temp
# Out:
#      level_0  level_1  student_id  course_id
# 0   november        0          23          1
# 1   november        1          15          5
# 2   november        2          18          6
# 3   november        3          23          4
# 4   november        4          16          9
# 5   november        5          18          1
# 6   november        6           1          1
# 7   november        7           7          8
# 8   november        8          22          3
# 9   november        9          15          1
# 10  november       10          19          4
# 11  november       11           1          6
# 12  november       12           7         10
# 13  november       13          11          7
# 14  november       14          13          3
# 15  november       15          24          4
# 16  november       16          21          1
# 17  november       17          16          5
# 18  november       18          23          3
# 19  november       19          17          7
# ...

# %%
ad=temp.merge(courses,how='inner',on='course_id')

# %%
ad.groupby('course_name')['student_id'].count().sort_values(ascending=False)
# Out:
# course_name
# python              9
# tableau             7
# power bi            6
# pyspark             6
# data analysis       5
# ms sxcel            5
# plotly              5
# machine learning    4
# pandas              4
# sql                 2
# Name: student_id, dtype: int64

# %% [markdown]
# # 4) Find The Student who never enrolled in any course

# %%
asd
# Out:
#     student_id  course_id       course_name  price
# 0            3          5           tableau   2499
# 1           16          7          ms sxcel   1599
# 2           12         10           pyspark   2499
# 3           12          1            python   2499
# 4           14          9            plotly    699
# 5            7          7          ms sxcel   1599
# 6            7          2               sql   3499
# 7           16          3     data analysis   4999
# 8           17         10           pyspark   2499
# 9           11          8            pandas   1099
# 10          14          6          power bi   1899
# 11          12          5           tableau   2499
# 12          12          7          ms sxcel   1599
# 13          18          8            pandas   1099
# 14           1         10           pyspark   2499
# 15           1          9            plotly    699
# 16           2          5           tableau   2499
# ...

# %%
aaa=pd.concat([nov,dec],ignore_index=False,keys=['november','december']).reset_index()
aaa
# Out:
#      level_0  level_1  student_id  course_id
# 0   november        0          23          1
# 1   november        1          15          5
# 2   november        2          18          6
# 3   november        3          23          4
# 4   november        4          16          9
# 5   november        5          18          1
# 6   november        6           1          1
# 7   november        7           7          8
# 8   november        8          22          3
# 9   november        9          15          1
# 10  november       10          19          4
# 11  november       11           1          6
# 12  november       12           7         10
# 13  november       13          11          7
# 14  november       14          13          3
# 15  november       15          24          4
# 16  november       16          21          1
# 17  november       17          16          5
# 18  november       18          23          3
# 19  november       19          17          7
# ...

# %%
ano=pd.merge(aaa,courses,how='right',on='course_id')
ano
# Out:
#      level_0  level_1  student_id  course_id       course_name  price
# 0   november      0.0        23.0          1            python   2499
# 1   november      5.0        18.0          1            python   2499
# 2   november      6.0         1.0          1            python   2499
# 3   november      9.0        15.0          1            python   2499
# 4   november     16.0        21.0          1            python   2499
# 5   november     21.0        25.0          1            python   2499
# 6   december      3.0        12.0          1            python   2499
# 7   december     23.0        14.0          1            python   2499
# 8   december     27.0        38.0          1            python   2499
# 9   november     22.0        19.0          2               sql   3499
# 10  december      6.0         7.0          2               sql   3499
# 11  november      8.0        22.0          3     data analysis   4999
# ...

# %%
ano[ano.isnull().any(axis=1)]['course_name']
# Out:
# 53    Numpy
# 54      C++
# Name: course_name, dtype: object

# %%
anna=pd.merge(students,aaa,how='left',on='student_id')

# %%
anna
# Out:
#     student_id                name  partner   level_0  level_1  course_id
# 0            1       Kailash Harjo       23  november      6.0        1.0
# 1            1       Kailash Harjo       23  november     11.0        6.0
# 2            1       Kailash Harjo       23  december     14.0       10.0
# 3            1       Kailash Harjo       23  december     15.0        9.0
# 4            2         Esha Butala        1  december     16.0        5.0
# 5            3      Parveen Bhalla        3  november     24.0        3.0
# 6            3      Parveen Bhalla        3  december      0.0        5.0
# 7            4         Marlo Dugal       14       NaN      NaN        NaN
# 8            5         Kusum Bahri        6       NaN      NaN        NaN
# 9            6  Lakshmi Contractor       10       NaN      NaN        NaN
# 10           7        Tarun Thaker        9  november      7.0        8.0
# 11           7        Tarun Thaker        9  november     12.0       10.0
# ...

# %%
anna[anna.isnull().any(axis=1)]['name']
# Out:
# 7            Marlo Dugal
# 8            Kusum Bahri
# 9     Lakshmi Contractor
# 15        Radheshyam Dey
# 16     Nitika Chatterjee
# 17        Aayushman Sant
# 43         Hanuman Hegde
# Name: name, dtype: object

# %% [markdown]
# #  find the Most loayal student ( highest enrolled person is most loay student)

# %%
abc=pd.merge(aaa,students,how='inner',on='student_id')
abc
# Out:
#      level_0  level_1  student_id  course_id                name  partner
# 0   november        0          23          1      Chhavi Lachman       18
# 1   november        1          15          5           Preet Sha       16
# 2   november        2          18          6     Fardeen Mahabir       13
# 3   november        3          23          4      Chhavi Lachman       18
# 4   november        4          16          9        Elias Dodiya       25
# 5   november        5          18          1     Fardeen Mahabir       13
# 6   november        6           1          1       Kailash Harjo       23
# 7   november        7           7          8        Tarun Thaker        9
# 8   november        8          22          3          Yash Sethi       21
# 9   november        9          15          1           Preet Sha       16
# 10  november       10          19          4        Qabeel Raman       12
# 11  november       11           1          6       Kailash Harjo       23
# ...

# %%
abc.groupby('name')['student_id'].count().sort_values(ascending=False)
# Out:
# name
# Chhavi Lachman        6
# Tarun Thaker          5
# Radha Dutt            4
# Elias Dodiya          4
# Kailash Harjo         4
# Pranab Natarajan      4
# Yash Sethi            3
# Fardeen Mahabir       3
# David Mukhopadhyay    3
# Shashank D’Alia       2
# Preet Sha             2
# Qabeel Raman          2
# Parveen Bhalla        2
# Yasmin Palan          2
# Radhika Suri          1
# Seema Kota            1
# Munni Varghese        1
# Esha Butala           1
# Name: student_id, dtype: int64

# %%
abc.groupby('name')['level_0'].nunique().sort_values(ascending=False)
# Out:
# name
# Chhavi Lachman        2
# Parveen Bhalla        2
# Yash Sethi            2
# Tarun Thaker          2
# David Mukhopadhyay    2
# Yasmin Palan          2
# Kailash Harjo         2
# Fardeen Mahabir       2
# Elias Dodiya          2
# Munni Varghese        1
# Pranab Natarajan      1
# Qabeel Raman          1
# Radha Dutt            1
# Radhika Suri          1
# Seema Kota            1
# Shashank D’Alia       1
# Esha Butala           1
# Preet Sha             1
# Name: level_0, dtype: int64

# %%
abc.groupby('name')['level_0'].unique()
# Out:
# name
# Chhavi Lachman        [november, december]
# David Mukhopadhyay    [november, december]
# Elias Dodiya          [november, december]
# Esha Butala                     [december]
# Fardeen Mahabir       [november, december]
# Kailash Harjo         [november, december]
# Munni Varghese                  [november]
# Parveen Bhalla        [november, december]
# Pranab Natarajan                [december]
# Preet Sha                       [november]
# Qabeel Raman                    [november]
# Radha Dutt                      [december]
# Radhika Suri                    [november]
# Seema Kota                      [november]
# Shashank D’Alia                 [november]
# Tarun Thaker          [november, december]
# Yash Sethi            [november, december]
# Yasmin Palan          [november, december]
# Name: level_0, dtype: object
