# %%
print("Hello world")
# Out:
# Hello world

# %%
a= input("Enter string")
# Out:
# Enter string asd

# %%
##Day 1

# %%
pip freeze
# Out:
# absl-py==2.1.0
# anyio==4.12.0
# argon2-cffi==25.1.0
# argon2-cffi-bindings==25.1.0
# arrow==1.4.0
# asgiref==3.8.1
# asttokens==2.4.1
# astunparse==1.6.3
# async-lru==2.0.5
# attrs==25.4.0
# babel==2.17.0
# beautifulsoup4==4.14.3
# bleach==6.3.0
# blinker==1.7.0
# cachetools==5.3.2
# certifi==2024.2.2
# cffi==2.0.0
# charset-normalizer==3.3.2
# click==8.1.7
# colorama==0.4.6
# comm==0.2.1
# contourpy==1.2.0
# cycler==0.12.1
# debugpy==1.8.1
# decorator==5.1.1
# defusedxml==0.7.1
# Django==5.0.6
# exceptiongroup==1.2.0
# executing==2.0.1
# fastjsonschema==2.21.2
# Flask==3.0.2
# flatbuffers==23.5.26
# fonttools==4.49.0
# fqdn==1.5.1
# gast==0.4.0
# google-auth==2.28.0
# google-auth-oauthlib==0.4.6
# google-pasta==0.2.0
# grpcio==1.60.1
# h11==0.16.0
# h5py==3.10.0
# httpcore==1.0.9
# httpx==0.28.1
# idna==3.6
# ipykernel==6.29.3
# ipython==8.22.2
# isoduration==20.11.0
# itsdangerous==2.1.2
# jedi==0.19.1
# Jinja2==3.1.3
# joblib==1.3.2
# json5==0.12.1
# jsonpointer==3.0.0
# ...

# %%
pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np

# %%
### creating 1d array using list

# %%
lists=[10,20,30,50,34.78,12,80]

print(lists,type(lists))
# Out:
# [10, 20, 30, 50, 34.78, 12, 80] <class 'list'>

# %%
##np,array

# %%
lists=[10,20,30,50,34.78,12,80,True,False]
arr=np.array(lists)
print(arr,type(arr))
# Out:
# [10.   20.   30.   50.   34.78 12.   80.    1.    0.  ] <class 'numpy.ndarray'>

# %%
##np,arrat arguments

# %%
lists=[10,20,30,50,34.78,12,80,True,False]
arr=np.array(lists,dtype=int)
print(arr,type(arr))
# Out:
# [10.   20.   30.   50.   34.78 12.   80.    1.    0.  ] <class 'numpy.ndarray'>

# %%
bool(-10000)
# Out:
# True

# %%
##size,shape,ndim

# %%
import numpy as np
lists=[10,20,30,40,50]
arr=np.array(lists)
arr
# Out:
# array([10, 20, 30, 40, 50])

# %%
arr.size
# Out:
# 5

# %%
arr.shape
# Out:
# (5,)

# %%
arr.ndim
# Out:
# 1

# %%
##creating a 2d array

# %%
lists1=[10,20,30,40]
lists2=[45,78,90,10]
lists3=[12,45,67,90]

list2d=[lists1,lists2,lists3]
list2d
# Out:
# [[10, 20, 30, 40], [45, 78, 90, 10], [12, 45, 67, 90]]

# %%
#creating a 2d array

# %%
arr2d=np.array(list2d)
arr2d
# Out:
# array([[10, 20, 30, 40],
#        [45, 78, 90, 10],
#        [12, 45, 67, 90]])

# %%
## application of numpy array in real life
